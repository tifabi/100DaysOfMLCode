# %% [markdown]
# # Bag of Words
#
# This Notebook explores the art of creating a Bag of Words prior to performing machine learning and data science processes on text.

# %% [markdown]
# ### Stemming and Lemmatization

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import HashingVectorizer

# %% [markdown]
# The data set we will use for this example contains 1,300 Headlines from Google News.

# %%
df = pd.read_csv('Data/gAlert_SNIPs2.csv',encoding = "ISO-8859-1")

# %% [markdown]
# We Stem and Lemmatize the data into different sets:

# %%
stemmer = SnowballStemmer('english') #define stemmer
dfStem=[' '.join([stemmer.stem(word) for word in text.split(' ')])
          for text in df['Summary']]

lemmer=WordNetLemmatizer() #define Lemmatizer
dfLem=[' '.join([lemmer.lemmatize(word) for word in text.split(' ')])
          for text in df['Summary']]

# %%
import spacy
import wordcloud
from spacy import displacy
from collections import Counter
import pandas as pd

nlp = spacy.load('en')

# %% [markdown]
# Convert the dataframes into strings, but lets only use the first 50 words for demo.

# %%
stemString = ''.join(dfStem[:50])
lemString = ''.join(dfLem[:50])

# %%
stemDoc = nlp(stemString)
lemDoc = nlp(lemString)

# %% [markdown]
# Create relationship rendering:

# %%
displacy.render(stemDoc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="325200" height="3024.5" style="max-width: none; height: 3024.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2934.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2934.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2934.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">fda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
# ...

# %%
displacy.render(lemDoc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="327825" height="2062.0" style="max-width: none; height: 2062.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1972.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1972.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1972.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">FDA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
# ...
